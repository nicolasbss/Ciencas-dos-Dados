# %% [markdown]
# ___
# # Ciência dos Dados - PROJETO 1

# %% [markdown]
# ## Nicolas Barbosa Stegmann
# ___

# %% [markdown]
# ## TÍTULO DO SEU PROJETO

# %% [markdown]
# ___
# ## Introdução
#
#    O projeto a ser desenvolvido tem como objetivo primário analisar o cenário nacional quanto a distribuição da situação de insegurança alimentar nas mais diversas regiões. Para realizar essa análise, pretende-se primeiramente separar cada região do país e calcular a relação entre o número de habitantes da região em situação de insegurança alimentar e a população total.
#    Então, pretende-se destrinchar o perfil da população analisada em relação a sua area de habitação (rural e urbana) e em relação a sua renda, para que mais dados sejam levantados em relação a situação de insegurança alimentar no Brasil.
#    Por último, será realizada uma comparação em relação aos dados levantados na PNAD de 2013 e de 2009, para que se compreenda como a situação está evoluindo no Brasil.

# %% [markdown]
# ## Variáveis
#    Para analisar se de fato há uma relação entre esses indicadores, foram escolhidas/criadas as seguintes variáveis:
# •	Região: Os estados brasileiros foram agrupados em regiões, para que a análise do cenário de insegurança seja feita em relação as regiões, e não em relação aos estados.
#
# •	Pessoas que assinalaram que passam por qualquer tipo de insegurança alimentar: Usada para levantar o pessoal nacional de pessoas que passam por insegurança alimentar no brasil.
#
# •	Pessoas que assinalaram que não passam por qualquer tipo de insegurança alimentar: Usada para levantar o pessoal nacional de pessoas que passam por insegurança alimentar no brasil.
#
# •	Domicílios em zona rural: Agrupamento de todas as áreas rurais da PNAD, utilizada para entender a dinâmica da insegurança alimentar nas zonas do brasil
#
# •	Domicílios em zona urbana: Agrupamento de todas as áreas urbanas da PNAD, mesmo objetivo da variável zona rural.
#
# •	Renda domiciliar per capita: Razão entre a renda domiciliar e o número de habitantes do domicílio.

# %% [markdown]
# ## Iniciando o projeto: Escolhendo variáveis e linhas para serem trabalhadas

# %%
import pandas as pd
dados = pd.read_csv('DOM2013.csv',sep=',')

#Criando novas variáveis

#Insegurança alimentar
dados.loc[(dados.V2103==1) | (dados.V2105==1) | (dados.V2107==1) | (dados.V2109==1),'Insegurança_Alimentar'] = 'Sim'
dados.loc[(dados.V2103==3) & (dados.V2105==3) & (dados.V2107==3) & (dados.V2109==3),'Insegurança_Alimentar'] = 'Não'

#Região
dados.loc[(dados.UF >= 10) & (dados.UF < 20), "Região"] = "Norte"
dados.loc[(dados.UF >= 20) & (dados.UF < 30), "Região"] = "Nordeste"
dados.loc[(dados.UF >= 30) & (dados.UF < 40), "Região"] = "Sudeste"
dados.loc[(dados.UF >= 40) & (dados.UF < 50), "Região"] = "Sul"
dados.loc[(dados.UF >= 50) & (dados.UF < 60), "Região"] = "Centro-Oeste"

#Area do domicílio
dados.loc[(dados.V4105 <= 3), "Área_do_domicílio"] = "Urbana"
dados.loc[(dados.V4105 >= 4), "Área_do_domicílio"] = "Rural"

#Selecionando algumas colunas iniciais
dados.UF = dados.UF.astype("category")
dados.UF.cat.categories=(['Rondônia', 'Acre', 'Amazonas', 'Roraima', 'Pará', 'Amapá', 'Tocantins', 'Maranhão', 'Piauí', 'Ceará', 'Rio Grande do Norte', 'Paraíba', 'Pernambuco', 'Alagoas', 'Sergipe', 'Bahia', 'Minas Gerais', 'Espírito Santo', 'Rio de Janeiro', 'São Paulo', 'Paraná', 'Santa Catarina', 'Rio Grande do Sul', 'Mato Grosso do Sul', 'Mato Grosso', 'Goiás', 'Distrito Federal'])

#Criando um DataFrame com essas variáveis
colunas = dados.loc[:,["UF", "Região", "Área_do_domicílio", "Insegurança_Alimentar"]]
colunas.columns = ["Estado", "Região", "Área_do_domicílio", "Insegurança_Alimentar"]
colunas
# Out:
#                   Estado        Região Área_do_domicílio Insegurança_Alimentar
# 0               Rondônia         Norte            Urbana                   NaN
# 1               Rondônia         Norte            Urbana                   NaN
# 2               Rondônia         Norte            Urbana                   Não
# 3               Rondônia         Norte            Urbana                   Não
# 4               Rondônia         Norte            Urbana                   Não
# 5               Rondônia         Norte            Urbana                   Não
# 6               Rondônia         Norte            Urbana                   Não
# 7               Rondônia         Norte            Urbana                   Não
# 8               Rondônia         Norte            Urbana                   Não
# 9               Rondônia         Norte            Urbana                   Não
# 10              Rondônia         Norte            Urbana                   Sim
# 11              Rondônia         Norte            Urbana                   Não
# 12              Rondônia         Norte            Urbana                   Não
# 13              Rondônia         Norte            Urbana                   NaN
# 14              Rondônia         Norte            Urbana                   Não
# 15              Rondônia         Norte            Urbana                   Não
# 16              Rondônia         Norte            Urbana                   Não
# 17              Rondônia         Norte            Urbana                   Não
# 18              Rondônia         Norte            Urbana                   Não
# 19              Rondônia         Norte            Urbana                   Não
# 20              Rondônia         Norte            Urbana                   Não
# 21              Rondônia         Norte            Urbana                   Não
# 22              Rondônia         Norte            Urbana                   Não
# 23              Rondônia         Norte            Urbana                   NaN
# 24              Rondônia         Norte            Urbana                   Não
# 25              Rondônia         Norte            Urbana                   Não
# 26              Rondônia         Norte            Urbana                   Não
# 27              Rondônia         Norte            Urbana                   NaN
# 28              Rondônia         Norte            Urbana                   Não
# 29              Rondônia         Norte            Urbana                   Não
# ...                  ...           ...               ...                   ...
# 148667  Distrito Federal  Centro-Oeste            Urbana                   Não
# 148668  Distrito Federal  Centro-Oeste            Urbana                   Não
# 148669  Distrito Federal  Centro-Oeste            Urbana                   Não
# 148670  Distrito Federal  Centro-Oeste            Urbana                   Não
# 148671  Distrito Federal  Centro-Oeste            Urbana                   Não
# 148672  Distrito Federal  Centro-Oeste            Urbana                   Não
# 148673  Distrito Federal  Centro-Oeste            Urbana                   Não
# 148674  Distrito Federal  Centro-Oeste            Urbana                   NaN
# 148675  Distrito Federal  Centro-Oeste            Urbana                   NaN
# 148676  Distrito Federal  Centro-Oeste            Urbana                   NaN
# 148677  Distrito Federal  Centro-Oeste            Urbana                   Não
# 148678  Distrito Federal  Centro-Oeste            Urbana                   Não
# 148679  Distrito Federal  Centro-Oeste            Urbana                   Não
# 148680  Distrito Federal  Centro-Oeste            Urbana                   Não
# 148681  Distrito Federal  Centro-Oeste            Urbana                   Sim
# 148682  Distrito Federal  Centro-Oeste            Urbana                   Não
# 148683  Distrito Federal  Centro-Oeste            Urbana                   Não
# 148684  Distrito Federal  Centro-Oeste            Urbana                   Sim
# 148685  Distrito Federal  Centro-Oeste            Urbana                   NaN
# 148686  Distrito Federal  Centro-Oeste            Urbana                   NaN
# 148687  Distrito Federal  Centro-Oeste            Urbana                   Não
# 148688  Distrito Federal  Centro-Oeste            Urbana                   Não
# 148689  Distrito Federal  Centro-Oeste            Urbana                   Não
# 148690  Distrito Federal  Centro-Oeste            Urbana                   Sim
# 148691  Distrito Federal  Centro-Oeste            Urbana                   NaN
# 148692  Distrito Federal  Centro-Oeste            Urbana                   Sim
# 148693  Distrito Federal  Centro-Oeste            Urbana                   Sim
# 148694  Distrito Federal  Centro-Oeste            Urbana                   Não
# 148695  Distrito Federal  Centro-Oeste            Urbana                   Sim
# 148696  Distrito Federal  Centro-Oeste            Urbana                   NaN
#
# [148697 rows x 4 columns]

# %% [markdown]
# ___
# ## Análise e Resultados

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())

# %%
#Se usar o arquivo descompactado

# %% [markdown]
# ___
# ## Conclusão

# %% [markdown]
# Descreva aqui suas conclusões!
